# %% [markdown]
# # Calidad del aire. Datos en tiempo real
#
# [Link](https://datos.madrid.es/portal/site/egob/menuitem.c05c1f754a33a9fbe4b2e4b284f1a5a0/?vgnextoid=41e01e007c9db410VgnVCM100000171f5a0aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextfmt=default) al dataset.
#
# > El Sistema Integral de la Calidad del Aire del Ayuntamiento de Madrid permite conocer en cada momento los niveles de contaminación atmosférica en el municipio.
# >
# > En este conjunto de datos puede obtener la información actualizada en tiempo real, actualizándose estos datos cada hora, y esta actualización se realizará entre los minutos 20 y 30.
# >
# > **Importante:** estos datos en tiempo real son los que salen automáticamente de las estaciones de medición y están pendientes de revisión y validación.
#
#
# Para más información sobre el contenido del fichero, consultar el documento [Interprete_ficheros_calidad_del_aire_global.pdf](https://datos.madrid.es/FWProjects/egob/Catalogo/MedioAmbiente/Aire/Ficheros/Interprete_ficheros_%20calidad_%20del_%20aire_global.pdf).

# %%
import pandas as pd

# %%
url = "https://www.mambiente.madrid.es/opendata/horario.txt"
COLUMNS = [
    "provincia",
    "municipio",
    "estacion",
    "magnitud",
    "punto_muestreo",
    "ano",
    "mes",
    "dia",
]

for i in range(1, 25):
    COLUMNS.append(f"H{i:02d}")
    COLUMNS.append(f"V{i:02d}")

df = pd.read_csv(url, names=COLUMNS)
df
# Out:
#     provincia  municipio  estacion  magnitud  punto_muestreo   ano  mes  dia  \
# 28         79          4         1        38               2  2024    3   23
# 28         79          4         6        48               2  2024    3   23
# 28         79          4         7         8               2  2024    3   23
# 28         79          4         8         8               2  2024    3   23
# 28         79          4        12         8               2  2024    3   23
# ..        ...        ...       ...       ...             ...   ...  ...  ...
# 28         79         60         7         8               2  2024    3   23
# 28         79         60         8         8               2  2024    3   23
# 28         79         60        10        47               2  2024    3   23
# 28         79         60        12         8               2  2024    3   23
# 28         79         60        14         6               2  2024    3   23
#
#      H01 V01  ...  H20 V20  H21 V21  H22 V22  H23 V23  H24 V24
# 28   3.0   V  ...    0   N    0   N    0   N    0   N    0   N
# 28   0.4   V  ...    0   N    0   N    0   N    0   N    0   N
# 28  14.0   V  ...    0   N    0   N    0   N    0   N    0   N
# 28  51.0   V  ...    0   N    0   N    0   N    0   N    0   N
# 28  72.0   V  ...    0   N    0   N    0   N    0   N    0   N
# ..   ...  ..  ...  ...  ..  ...  ..  ...  ..  ...  ..  ...  ..
# 28   1.0   V  ...    0   N    0   N    0   N    0   N    0   N
# 28  44.0   V  ...    0   N    0   N    0   N    0   N    0   N
# 28  99.0   V  ...    0   N    0   N    0   N    0   N    0   N
# 28  45.0   V  ...    0   N    0   N    0   N    0   N    0   N
# 28  25.0   V  ...    0   N    0   N    0   N    0   N    0   N
#
# [142 rows x 56 columns]

# %%
column_nan = df.isnull().sum()
column_nan[column_nan > 0]
# Out:
# Series([], dtype: int64)

# %%
df.iloc[0]
# Out:
# PROVINCIA                      79
# MUNICIPIO                       4
# ESTACION                        1
# MAGNITUD                       38
# TECNICA                         2
# AÑO                          2024
# MES                             3
# DIA                            23
# DATO                          3.0
# CÓDIGO DE VALIDACIÓN            V
# HORA 1                        3.0
# CODIGO VALIDACION HORA 1        V
# HORA 2                        3.0
# CODIGO VALIDACION HORA 2        V
# HORA 3                        2.0
# CODIGO VALIDACION HORA 3        V
# HORA 4                        2.0
# CODIGO VALIDACION HORA 4        V
# HORA 5                        2.0
# CODIGO VALIDACION HORA 5        V
# HORA 6                        2.0
# CODIGO VALIDACION HORA 6        V
# HORA 7                        2.0
# CODIGO VALIDACION HORA 7        V
# HORA 8                        2.0
# CODIGO VALIDACION HORA 8        V
# HORA 9                        2.0
# CODIGO VALIDACION HORA 9        V
# HORA 10                       2.0
# CODIGO VALIDACION HORA 10       V
# HORA 11                       2.0
# CODIGO VALIDACION HORA 11       V
# HORA 12                       2.0
# CODIGO VALIDACION HORA 12       V
# HORA 13                         0
# CODIGO VALIDACION HORA 13       N
# HORA 14                         0
# CODIGO VALIDACION HORA 14       N
# HORA 15                         0
# CODIGO VALIDACION HORA 15       N
# HORA 16                         0
# CODIGO VALIDACION HORA 16       N
# HORA 17                         0
# CODIGO VALIDACION HORA 17       N
# HORA 18                         0
# CODIGO VALIDACION HORA 18       N
# HORA 19                         0
# CODIGO VALIDACION HORA 19       N
# HORA 20                         0
# CODIGO VALIDACION HORA 20       N
# HORA 21                         0
# CODIGO VALIDACION HORA 21       N
# HORA 22                         0
# CODIGO VALIDACION HORA 22       N
# HORA 23                         0
# CODIGO VALIDACION HORA 23       N
# Name: 28, dtype: object
