# %%
import folium
import pandas as pd
from scipy.spatial import Voronoi
import branca.colormap as cm
import numpy as np

estaciones = pd.read_csv('https://datos.madrid.es/egob/catalogo/211346-1-estaciones-acusticas.csv', sep=';', parse_dates=['FECHA ALTA'])
ruido = pd.read_csv('https://datos.madrid.es/egob/catalogo/215885-10749127-contaminacion-ruido.csv', sep=';', decimal=',')

# %%
estaciones.head()
# Out:
#     NMT            NOMBRE                                          DIRECCION  \
# 0  RF 1      Pº Recoletos             Frente al Nº 23 del Paseo de Recoletos
# 1  RF 2          Carlos V  Plaza del Emperador Carlos V, junto al Nº 1 de...
# 2  RF 3  Plaza del Carmen  Plaza del Carmen frente al Nº 3 de la Calle de...
# 3  RF 4   Plaza de España              Frente al Nº 18 de la Plaza de España
# 4  RF 5      Bº del Pilar  Parque de La Vaguada semiesquina de Avenida Mo...
#
#    LONGITUD    LATITUD  X (ETRS89)  Y (ETRS89)  ALTITUD  FECHA ALTA
# 0 -3.691877  40.422599      441307     4474893      648  07/03/2011
# 1 -3.691509  40.409121      441327     4473397      629  01/12/1998
# 2 -3.703175  40.419251      440346     4474529      657  01/11/1999
# 3 -3.712253  40.424005      439580     4475063      637  01/12/1998
# 4 -3.711543  40.478197      439688     4481078      673  07/06/1999

# %%
estaciones.dtypes
# Out:
# NMT            object
# NOMBRE         object
# DIRECCION      object
# LONGITUD      float64
# LATITUD       float64
# X (ETRS89)      int64
# Y (ETRS89)      int64
# ALTITUD         int64
# FECHA ALTA     object
# dtype: object

# %%
estaciones['NMT'] = estaciones['NMT'].str[3:].astype(int)

# %%
estaciones.head()
# Out:
#    NMT            NOMBRE                                          DIRECCION  \
# 0    1      Pº Recoletos             Frente al Nº 23 del Paseo de Recoletos
# 1    2          Carlos V  Plaza del Emperador Carlos V, junto al Nº 1 de...
# 2    3  Plaza del Carmen  Plaza del Carmen frente al Nº 3 de la Calle de...
# 3    4   Plaza de España              Frente al Nº 18 de la Plaza de España
# 4    5      Bº del Pilar  Parque de La Vaguada semiesquina de Avenida Mo...
#
#    LONGITUD    LATITUD  X (ETRS89)  Y (ETRS89)  ALTITUD  FECHA ALTA
# 0 -3.691877  40.422599      441307     4474893      648  07/03/2011
# 1 -3.691509  40.409121      441327     4473397      629  01/12/1998
# 2 -3.703175  40.419251      440346     4474529      657  01/11/1999
# 3 -3.712253  40.424005      439580     4475063      637  01/12/1998
# 4 -3.711543  40.478197      439688     4481078      673  07/06/1999

# %%
estaciones.tail()
# Out:
#     NMT                Nombre  \
# 26   48            Castellana
# 27   50     Plaza de Castilla
# 28   54  Ensanche de Vallecas
# 29   55           Embajada II
# 30   86           Tres Olivos
#
#                                             Dirección  X (ETRS89)  Y (ETRS89)  \
# 26  Jardín de Las Bellas Artes,a la altura del nº2...      441450     4476811
# 27                Frente al nº 9 de la Plaza Castilla      441610     4479662
# 28  Esquina entre la Avenida de la Gavia y la Aven...      448033     4469339
# 29                  Frente al nº 13 de la Calle Riaño      450779     4479239
# 30  Frente al nº 23 de la Avenida del Campo de Cal...      441557     4483544
#
#           lat       lon
# 26  40.439887 -3.690369
# 27  40.465581 -3.688744
# 28  40.373011 -3.612142
# 29  40.462364 -3.580564
# 30  40.500548 -3.689727

# %%
ruido.head()
# Out:
#    NMT  anio  mes  dia tipo  LAEQ  LAS01  LAS10  LAS50  LAS90  LAS99
# 0    3  2014    1    1    D  57.4   66.6   61.1   54.3   49.1   45.0
# 1    3  2014    1    1    E  58.7   66.6   62.0   56.0   52.1   48.5
# 2    3  2014    1    1    N  65.9   72.5   66.1   60.9   56.2   52.1
# 3    3  2014    1    1    T  62.2   69.3   63.8   56.5   50.3   45.8
# 4    4  2014    1    1    D  67.3   72.4   67.0   63.2   59.5   56.2

# %%
ruido['LAS01'].max()
# Out:
# 106.3

# %%
coords = estaciones[['LATITUD', 'LONGITUD']].to_numpy()
min_lat = estaciones['LATITUD'].min() - 0.2 
max_lat = estaciones['LATITUD'].max() + 0.2
min_lon = estaciones['LONGITUD'].min() - 0.2
max_lon = estaciones['LONGITUD'].max() + 0.2

# %%
class VoronoiRegion:
    def __init__(self, region_id, station_id):
        self.id = region_id
        self.station_id = station_id
        self.vertices = []
        self.is_inf = False
        self.point_inside = None

    def __str__(self):
        text = f'region id={self.id}' + f'({self.station_id})'
        if self.point_inside:
            point_idx, point = self.point_inside
            text = f'{text}[point:{point}(point_id:{point_idx})]'
        text += ', vertices: '
        if self.is_inf:
            text += '(inf)'
        for v in self.vertices:
            text += f'{v}'
        return text

    def __repr__(self):
        return str(self)

    def add_vertex(self, vertex, vertices):
        if vertex == -1:
            self.is_inf = True
        else:
            point = vertices[vertex]
            self.vertices.append(point)
        
    @property
    def name(self):
        return estaciones[estaciones['NMT'] == self.station_id]['NOMBRE'].values[0]
    
    @property
    def coords(self):
        return self.point_inside[1]

def voronoi_to_voronoi_regions(voronoi, ids):
    voronoi_regions = []
    if len(ids) != len(voronoi.points):
        # Append None to the names list
        ids = np.append(ids, [None] * (len(voronoi.points) - len(ids)))

    for i, (point_region, station_id) in enumerate(zip(voronoi.point_region, ids)):
        region = voronoi.regions[point_region]
        vr = VoronoiRegion(point_region, station_id)
        for r in region:
            vr.add_vertex(r, voronoi.vertices)
        vr.point_inside = (i, voronoi.points[i])
        voronoi_regions.append(vr)
    return voronoi_regions


vor = Voronoi(np.append(coords, [[min_lat, min_lon], [min_lat, max_lon], [max_lat, min_lon], [max_lat, max_lon]], axis=0))
regions = voronoi_to_voronoi_regions(vor, estaciones['NMT'])
for r in regions:
    print(r)
# Out:
# region id=31(1)[point:[40.422599 -3.691877](point_id:0)], vertices: [40.43075631 -3.70043937][40.41574267 -3.69599029][40.41596666 -3.68778671][40.42969841 -3.68630657]
# region id=32(2)[point:[40.409121 -3.691509](point_id:1)], vertices: [40.41574267 -3.69599029][40.40107985 -3.70872254][40.39686427 -3.70499418][40.40847812 -3.67757403][40.41596666 -3.68778671]
# region id=34(3)[point:[40.419251 -3.703175](point_id:2)], vertices: [40.43075631 -3.70043937][40.43200519 -3.70227964][40.40548453 -3.71616807][40.40383089 -3.71475418][40.40107985 -3.70872254][40.41574267 -3.69599029]
# region id=19(4)[point:[40.424005 -3.712253](point_id:3)], vertices: [40.43200519 -3.70227964][40.40548453 -3.71616807][40.41100081 -3.72441919][40.42061762 -3.72964388][40.44010819 -3.73220901][40.43321999 -3.70304503]
# region id=7(5)[point:[40.478197 -3.711543](point_id:4)], vertices: [40.48298478 -3.69403358][40.51837785 -3.73023633][40.46846153 -3.76176043][40.45730683 -3.74342483][40.46242622 -3.70535502]
for i, r in enumerate(regions):
    if r.is_inf:
        continue
    try:
        dBA = ruido[(ruido['NMT'] == r.station_id) & (ruido['anio'] == anio) & (ruido['mes'] == mes) & (ruido['dia'] == dia) & (ruido['tipo'] == tipo)][col].values[0]
        color = cmap(dBA)
    except:
        color = 'gray'
        dBA = -1
    folium.Polygon(locations=r.vertices, color=color, fill_color=color, fill_opacity=0.5, popup=dBA).add_to(m)
    folium.Marker(r.coords, icon=folium.Icon(color='blue'), popup=r.name).add_to(m)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_75d11f759177a520161a4e24bfc98e75 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_75d11f759177a520161a4e24bfc98e75&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_75d11f759177a520161a4e24bfc98e75 = L.map(
#                 &quot;map_75d11f759177a520161a4e24bfc98e75&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_54ccef940a0c6e898406506a6d3be779 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_54ccef940a0c6e898406506a6d3be779.addTo(map_75d11f759177a520161a4e24bfc98e75);
#
#
#             var polygon_b636ca145eb2e8096f09b30d0f7006b9 = L.polygon(
#                 [[40.43075631294369, -3.7004393683603674], [40.415742667841336, -3.6959902903109243], [40.41596665642012, -3.6877867086132428], [40.429698409328225, -3.6863065701945144]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffde00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffde00ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_75d11f759177a520161a4e24bfc98e75);
#
#
#         var popup_648759966ca2940d9390a466cfddac64 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6fac4f92b0aff016c8fd4516015cd87d = $(`&lt;div id=&quot;html_6fac4f92b0aff016c8fd4516015cd87d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;62.2&lt;/div&gt;`)[0];
#                 popup_648759966ca2940d9390a466cfddac64.setContent(html_6fac4f92b0aff016c8fd4516015cd87d);
#
#
#
#         polygon_b636ca145eb2e8096f09b30d0f7006b9.bindPopup(popup_648759966ca2940d9390a466cfddac64)
#         ;
#
#
#
#
#             var marker_c39f369035f15129468d5eaf0161826f = L.marker(
#                 [40.422599, -3.691877],
#                 {}
#             ).addTo(map_75d11f759177a520161a4e24bfc98e75);
#
#
#             var icon_43e18306289cd848aa04c0677406f5f6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c39f369035f15129468d5eaf0161826f.setIcon(icon_43e18306289cd848aa04c0677406f5f6);
#
#
#         var popup_b12b426dfcf3ae8905f231b4951be059 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae401a5477bfa32cd7906156b6e677d6 = $(`&lt;div id=&quot;html_ae401a5477bfa32cd7906156b6e677d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pº Recoletos&lt;/div&gt;`)[0];
#                 popup_b12b426dfcf3ae8905f231b4951be059.setContent(html_ae401a5477bfa32cd7906156b6e677d6);
#
#
#
#         marker_c39f369035f15129468d5eaf0161826f.bindPopup(popup_b12b426dfcf3ae8905f231b4951be059)
#         ;
#
#
#
#
#             var polygon_5ace9c80aa51fc782416d5daef64628f = L.polygon(
#                 [[40.415742667841336, -3.6959902903109243], [40.40107984760372, -3.7087225352112463], [40.3968642714826, -3.704994179496831], [40.40847812254658, -3.677574027835656], [40.41596665642012, -3.6877867086132428]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffd300ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffd300ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_75d11f759177a520161a4e24bfc98e75);
#
#
#         var popup_e9ff2cdd01e2bffa9135cb471021e38d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_451308df2b88fe1fae226a14035f94b9 = $(`&lt;div id=&quot;html_451308df2b88fe1fae226a14035f94b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;64.6&lt;/div&gt;`)[0];
#                 popup_e9ff2cdd01e2bffa9135cb471021e38d.setContent(html_451308df2b88fe1fae226a14035f94b9);
#
#
#
#         polygon_5ace9c80aa51fc782416d5daef64628f.bindPopup(popup_e9ff2cdd01e2bffa9135cb471021e38d)
#         ;
#
#
#
#
#             var marker_8d592166cf
