# %% [markdown]
# # Calidad del aire. Datos en tiempo real
#
# [Link](https://datos.madrid.es/portal/site/egob/menuitem.c05c1f754a33a9fbe4b2e4b284f1a5a0/?vgnextoid=41e01e007c9db410VgnVCM100000171f5a0aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextfmt=default) al dataset.
#
# > El Sistema Integral de la Calidad del Aire del Ayuntamiento de Madrid permite conocer en cada momento los niveles de contaminación atmosférica en el municipio.
# >
# > En este conjunto de datos puede obtener la información actualizada en tiempo real, actualizándose estos datos cada hora, y esta actualización se realizará entre los minutos 20 y 30.
# >
# > **Importante:** estos datos en tiempo real son los que salen automáticamente de las estaciones de medición y están pendientes de revisión y validación.
#
#
# Para más información sobre el contenido del fichero, consultar el documento [Interprete_ficheros_calidad_del_aire_global.pdf](https://datos.madrid.es/FWProjects/egob/Catalogo/MedioAmbiente/Aire/Ficheros/Interprete_ficheros_%20calidad_%20del_%20aire_global.pdf).

# %%
import pandas as pd

# %%
# URL of the XML file
url = "https://www.mambiente.madrid.es/opendata/horario.xml"

# Namespace dictionary
namespaces = {"bdca": "http://bdca"}

# Read the XML file directly into a DataFrame using the correct namespace
df = pd.read_xml(url, xpath=".//bdca:Dato_Horario", namespaces=namespaces)
df
# Out:
#      provincia  municipio  estacion  magnitud  punto_muestreo   ano  mes  dia  \
# 0           28         79         4         1   28079004_1_38  2024    4   15
# 1           28         79         4         6   28079004_6_48  2024    4   15
# 2           28         79         4         7    28079004_7_8  2024    4   15
# 3           28         79         4         8    28079004_8_8  2024    4   15
# 4           28         79         4        12   28079004_12_8  2024    4   15
# ..         ...        ...       ...       ...             ...   ...  ...  ...
# 124         28         79        60         7    28079060_7_8  2024    4   15
# 125         28         79        60         8    28079060_8_8  2024    4   15
# 126         28         79        60        10  28079060_10_47  2024    4   15
# 127         28         79        60        12   28079060_12_8  2024    4   15
# 128         28         79        60        14   28079060_14_6  2024    4   15
#
#       H01 V01  ...    H20 V20    H21 V21    H22 V22  H23 V23  H24 V24
# 0     1.0   N  ...    1.0   V    2.0   V    2.0   V  0.0   N  0.0   N
# 1     0.4   V  ...    0.3   V    0.3   V    0.3   V  0.0   N  0.0   N
# 2     6.0   V  ...    3.0   V    4.0   V    3.0   V  0.0   N  0.0   N
# 3    58.0   V  ...   16.0   V   18.0   V   23.0   V  0.0   N  0.0   N
# 4    67.0   V  ...   20.0   V   24.0   V   27.0   V  0.0   N  0.0   N
# ..    ...  ..  ...    ...  ..    ...  ..    ...  ..  ...  ..  ...  ..
# 124   1.0   V  ...    1.0   V    1.0   V    1.0   V  0.0   N  0.0   N
# 125  17.0   V  ...   10.0   V   13.0   V   16.0   V  0.0   N  0.0   N
# 126  24.0   V  ...  110.0   V  143.0   V  111.0   V  0.0   N  0.0   N
# 127  18.0   V  ...   12.0   V   15.0   V   18.0   V  0.0   N  0.0   N
# 128  83.0   V  ...   68.0   V   61.0   V   59.0   V  0.0   N  0.0   N
#
# [129 rows x 56 columns]

# %%
df = pd.read_csv("https://www.mambiente.madrid.es/opendata/horario.csv", sep=";")
df
# Out:
#      PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  DIA  \
# 0           28         79         4         1   28079004_1_38  2024    4   15
# 1           28         79         4         6   28079004_6_48  2024    4   15
# 2           28         79         4         7    28079004_7_8  2024    4   15
# 3           28         79         4         8    28079004_8_8  2024    4   15
# 4           28         79         4        12   28079004_12_8  2024    4   15
# ..         ...        ...       ...       ...             ...   ...  ...  ...
# 124         28         79        60         7    28079060_7_8  2024    4   15
# 125         28         79        60         8    28079060_8_8  2024    4   15
# 126         28         79        60        10  28079060_10_47  2024    4   15
# 127         28         79        60        12   28079060_12_8  2024    4   15
# 128         28         79        60        14   28079060_14_6  2024    4   15
#
#       H01 V01  ...    H20 V20    H21 V21    H22 V22  H23 V23  H24 V24
# 0     1.0   N  ...    1.0   V    2.0   V    2.0   V    0   N    0   N
# 1     0.4   V  ...    0.3   V    0.3   V    0.3   V    0   N    0   N
# 2     6.0   V  ...    3.0   V    4.0   V    3.0   V    0   N    0   N
# 3    58.0   V  ...   16.0   V   18.0   V   23.0   V    0   N    0   N
# 4    67.0   V  ...   20.0   V   24.0   V   27.0   V    0   N    0   N
# ..    ...  ..  ...    ...  ..    ...  ..    ...  ..  ...  ..  ...  ..
# 124   1.0   V  ...    1.0   V    1.0   V    1.0   V    0   N    0   N
# 125  17.0   V  ...   10.0   V   13.0   V   16.0   V    0   N    0   N
# 126  24.0   V  ...  110.0   V  143.0   V  111.0   V    0   N    0   N
# 127  18.0   V  ...   12.0   V   15.0   V   18.0   V    0   N    0   N
# 128  83.0   V  ...   68.0   V   61.0   V   59.0   V    0   N    0   N
#
# [129 rows x 56 columns]

# %%
df.magnitud.value_counts()
# Out:
# magnitud
# 7     24
# 8     24
# 12    24
# 10    13
# 14    13
# 9      8
# 20     5
# 30     5
# 35     5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
column_nan = df.isnull().sum()
column_nan[column_nan > 0]
# Out:
# Series([], dtype: int64)

# %%
df.iloc[0]
# Out:
# provincia                    28
# municipio                    79
# estacion                      4
# magnitud                      1
# punto_muestreo    28079004_1_38
# ano                        2024
# mes                           4
# dia                          15
# H01                         1.0
# V01                           N
# H02                         1.0
# V02                           N
# H03                         1.0
# V03                           N
# H04                         1.0
# V04                           N
# H05                         1.0
# V05                           N
# H06                         1.0
# V06                           N
# H07                         1.0
# V07                           N
# H08                         1.0
# V08                           N
# H09                         4.0
# V09                           N
# H10                         5.0
# V10                           V
# H11                         5.0
# V11                           V
# H12                         6.0
# V12                           V
# H13                         4.0
# V13                           V
# H14                         3.0
# V14                           V
# H15                         2.0
# V15                           V
# H16                         2.0
# V16                           V
# H17                         2.0
# V17                           V
# H18                         2.0
# V18                           V
# H19                         2.0
# V19                           V
# H20                         1.0
# V20                           V
# H21                         2.0
# V21                           V
# H22                         2.0
# V22                           V
# H23                         0.0
# V23                           N
# H24                         0.0
# V24                           N
# Name: 0, dtype: object
